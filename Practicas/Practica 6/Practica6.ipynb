# %% [markdown]
# # Practica 6

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import seaborn.objects as so

import matplotlib.pyplot as plt

from sklearn import linear_model    # Herramientas de modelos lineales
from sklearn.metrics import mean_squared_error, r2_score    # Medidas de desempeño
from sklearn.preprocessing import PolynomialFeatures    # Herramientas de polinomios

from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split

from formulaic import model_matrix
from formulaic import Formula

# %% [markdown]
# ## Ejercicio 1

# %%
penguins = sns.load_dataset("penguins")
penguins.dropna().reset_index(drop = True)

ejercicio1 = penguins

ejercicio1 = ejercicio1[ejercicio1["island"] == "Biscoe"]
ejercicio1 = ejercicio1[ejercicio1["bill_length_mm"] > 48]

ejercicio1.reset_index(drop=True).head()
# Out:
#   species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Gentoo  Biscoe            50.0           16.3              230.0
# 1  Gentoo  Biscoe            48.7           14.1              210.0
# 2  Gentoo  Biscoe            50.0           15.2              218.0
# 3  Gentoo  Biscoe            49.0           16.1              216.0
# 4  Gentoo  Biscoe            48.4           14.6              213.0
#
#    body_mass_g     sex
# 0       5700.0    Male
# 1       4450.0  Female
# 2       5700.0    Male
# 3       5550.0    Male
# 4       5850.0    Male

# %% [markdown]
# ## Ejercicio 2

# %%
ejercicio2 = penguins[penguins["species"] == "Adelie"]
ejercicio2 = ejercicio2[ejercicio2["sex"] == "Male"]
ejercicio2 = ejercicio2[ejercicio2["island"] != "Biscoe"]

ejercicio2.reset_index(drop=True)
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.3           20.6              190.0
# 2   Adelie  Torgersen            39.2           19.6              195.0
# 3   Adelie  Torgersen            38.6           21.2              191.0
# 4   Adelie  Torgersen            34.6           21.1              198.0
# 5   Adelie  Torgersen            42.5           20.7              197.0
# 6   Adelie  Torgersen            46.0           21.5              194.0
# 7   Adelie      Dream            37.2           18.1              178.0
# 8   Adelie      Dream            40.9           18.9              184.0
# 9   Adelie      Dream            39.2           21.1              196.0
# 10  Adelie      Dream            38.8           20.0              190.0
# 11  Adelie      Dream            39.8           19.1              184.0
# ...

# %% [markdown]
# ## Ejercicio 3

# %%
ejercicio3 = penguins.drop("sex", axis=1).drop("body_mass_g", axis=1)

ejercicio3.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0

# %% [markdown]
# ## Ejercicio 4

# %% [markdown]
# Ya esta hecho al inicio del punto uno por pura inercia

# %% [markdown]
# ## Ejercicio 5

# %% [markdown]
# ### a

# %%
ejercicio5 = penguins.rename(columns={"species":"especies"})

ejercicio5.head()
# Out:
#   especies     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 3   Adelie  Torgersen             NaN            NaN                NaN
# 4   Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# ### b

# %%
ejercicio5 = ejercicio5.rename(columns={"flipper_length_mm":"aleta_mm","body_mass_g":"peso_g"})

ejercicio5.head()
# Out:
#   especies     island  bill_length_mm  bill_depth_mm  aleta_mm  peso_g     sex
# 0   Adelie  Torgersen            39.1           18.7     181.0  3750.0    Male
# 1   Adelie  Torgersen            39.5           17.4     186.0  3800.0  Female
# 2   Adelie  Torgersen            40.3           18.0     195.0  3250.0  Female
# 3   Adelie  Torgersen             NaN            NaN       NaN     NaN     NaN
# 4   Adelie  Torgersen            36.7           19.3     193.0  3450.0  Female

# %% [markdown]
# ### c

# %%
ejercicio5 = ejercicio5.rename(index={0:"cero"})

ejercicio5.head()
# Out:
#      especies     island  bill_length_mm  bill_depth_mm  aleta_mm  peso_g  \
# cero   Adelie  Torgersen            39.1           18.7     181.0  3750.0
# 1      Adelie  Torgersen            39.5           17.4     186.0  3800.0
# 2      Adelie  Torgersen            40.3           18.0     195.0  3250.0
# 3      Adelie  Torgersen             NaN            NaN       NaN     NaN
# 4      Adelie  Torgersen            36.7           19.3     193.0  3450.0
#
#          sex
# cero    Male
# 1     Female
# 2     Female
# 3        NaN
# 4     Female

# %% [markdown]
# ### d

# %%
ejercicio5 = ejercicio5.rename(columns=str.upper)

ejercicio5.head()
# Out:
#      ESPECIES     ISLAND  BILL_LENGTH_MM  BILL_DEPTH_MM  ALETA_MM  PESO_G  \
# cero   Adelie  Torgersen            39.1           18.7     181.0  3750.0
# 1      Adelie  Torgersen            39.5           17.4     186.0  3800.0
# 2      Adelie  Torgersen            40.3           18.0     195.0  3250.0
# 3      Adelie  Torgersen             NaN            NaN       NaN     NaN
# 4      Adelie  Torgersen            36.7           19.3     193.0  3450.0
#
#          SEX
# cero    Male
# 1     Female
# 2     Female
# 3        NaN
# 4     Female

# %% [markdown]
# ### e

# %% [markdown]
# Un error ya que el indice cero no es un numero, por lo tanto voy a cambiar esto antes de correrlo. Ahora si va a mostrar los indices pero aplicados la raiz cuadrada

# %%
ejercicio5 = ejercicio5.rename(index={"cero":0})
ejercicio5 = ejercicio5.rename(index=np.sqrt)

ejercicio5.head()
# Out:
#          ESPECIES     ISLAND  BILL_LENGTH_MM  BILL_DEPTH_MM  ALETA_MM  PESO_G  \
# 0.000000   Adelie  Torgersen            39.1           18.7     181.0  3750.0
# 1.000000   Adelie  Torgersen            39.5           17.4     186.0  3800.0
# 1.414214   Adelie  Torgersen            40.3           18.0     195.0  3250.0
# 1.732051   Adelie  Torgersen             NaN            NaN       NaN     NaN
# 2.000000   Adelie  Torgersen            36.7           19.3     193.0  3450.0
#
#              SEX
# 0.000000    Male
# 1.000000  Female
# 1.414214  Female
# 1.732051     NaN
# 2.000000  Female

# %% [markdown]
# ### f

# %% [markdown]
# podemos usar una lambda function para no hacer una funcion aparte, por por ejemplo vamos a mostrarlo

# %%
def suma_uno(x):
    return x + 1

ejercicio5 = ejercicio5.rename(index=suma_uno)

ejercicio5.head()
# Out:
#          ESPECIES     ISLAND  BILL_LENGTH_MM  BILL_DEPTH_MM  ALETA_MM  PESO_G  \
# 1.000000   Adelie  Torgersen            39.1           18.7     181.0  3750.0
# 2.000000   Adelie  Torgersen            39.5           17.4     186.0  3800.0
# 2.414214   Adelie  Torgersen            40.3           18.0     195.0  3250.0
# 2.732051   Adelie  Torgersen             NaN            NaN       NaN     NaN
# 3.000000   Adelie  Torgersen            36.7           19.3     193.0  3450.0
#
#              SEX
# 1.000000    Male
# 2.000000  Female
# 2.414214  Female
# 2.732051     NaN
# 3.000000  Female

# %% [markdown]
# ### g

# %%
ejercicio5 = ejercicio5.rename(index=lambda a: a * 2)

ejercicio5.head()
# Out:
#          ESPECIES     ISLAND  BILL_LENGTH_MM  BILL_DEPTH_MM  ALETA_MM  PESO_G  \
# 2.000000   Adelie  Torgersen            39.1           18.7     181.0  3750.0
# 4.000000   Adelie  Torgersen            39.5           17.4     186.0  3800.0
# 4.828427   Adelie  Torgersen            40.3           18.0     195.0  3250.0
# 5.464102   Adelie  Torgersen             NaN            NaN       NaN     NaN
# 6.000000   Adelie  Torgersen            36.7           19.3     193.0  3450.0
#
#              SEX
# 2.000000    Male
# 4.000000  Female
# 4.828427  Female
# 5.464102     NaN
# 6.000000  Female

# %% [markdown]
# ### h

# %%
ejercicio5 = ejercicio5.rename(columns=lambda a: a.lower())

ejercicio5.head()
# Out:
#          especies     island  bill_length_mm  bill_depth_mm  aleta_mm  peso_g  \
# 2.000000   Adelie  Torgersen            39.1           18.7     181.0  3750.0
# 4.000000   Adelie  Torgersen            39.5           17.4     186.0  3800.0
# 4.828427   Adelie  Torgersen            40.3           18.0     195.0  3250.0
# 5.464102   Adelie  Torgersen             NaN            NaN       NaN     NaN
# 6.000000   Adelie  Torgersen            36.7           19.3     193.0  3450.0
#
#              sex
# 2.000000    Male
# 4.000000  Female
# 4.828427  Female
# 5.464102     NaN
# 6.000000  Female

# %% [markdown]
# ## Ejercicio 6

# %% [markdown]
# ### a

# %%
[saludo + "!" for saludo in ["hola", "chau"]]
# Out:
# ['hola!', 'chau!']

# %% [markdown]
# ### b

# %%
ejercicio6 = penguins

ejercicio6.columns = [col.upper() for col in ejercicio6.columns]

ejercicio6.head()
# Out:
#   SPECIES     ISLAND  BILL_LENGTH_MM  BILL_DEPTH_MM  FLIPPER_LENGTH_MM  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    BODY_MASS_G     SEX
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# ## Ejercicio 7

# %%
ejercicio7 = sns.load_dataset("penguins").dropna().reset_index(drop=True)

ejercicio7.columns = [col.upper() if col.startswith("bill") else col for col in ejercicio7.columns]

ejercicio7.head()
# Out:
#   species     island  BILL_LENGTH_MM  BILL_DEPTH_MM  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen            36.7           19.3              193.0
# 4  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3       3450.0  Female
# 4       3650.0    Male

# %% [markdown]
# ## Ejercicio 8

# %%
ejercicio8 = sns.load_dataset("penguins").dropna().reset_index(drop=True)

ejercicio8["peso_bin"] = ["chico" if peso < 4000 else "grande" for peso in ejercicio8["body_mass_g"]]

ejercicio8
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen            36.7           19.3              193.0
# 4    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 328  Gentoo     Biscoe            47.2           13.7              214.0
# 329  Gentoo     Biscoe            46.8           14.3              215.0
# 330  Gentoo     Biscoe            50.4           15.7              222.0
# 331  Gentoo     Biscoe            45.2           14.8              212.0
# 332  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex peso_bin
# 0         3750.0    Male    chico
# ...

# %% [markdown]
# ## Ejercicio 9

# %%
ejercicio9 = sns.load_dataset("penguins").dropna().reset_index(drop=True)

ejercicio9 = ejercicio9[ejercicio9["sex"] == "Male"]
ejercicio9 = ejercicio9[ejercicio9["flipper_length_mm"] >= 200]

ejercicio9 = ejercicio9[[col for col in ejercicio9.columns if col.endswith("_mm")]]

ejercicio9.reset_index(drop=True).head()
# Out:
#    bill_length_mm  bill_depth_mm  flipper_length_mm
# 0            42.0           19.5              200.0
# 1            41.1           18.1              205.0
# 2            40.8           18.9              208.0
# 3            41.0           20.0              203.0
# 4            41.4           18.5              202.0

# %% [markdown]
# ## Ejercicio 10

# %% [markdown]
# ### a

# %%
ejercicio10 = sns.load_dataset("penguins").dropna().reset_index(drop=True)

ejercicio10 = ejercicio10[ejercicio10["island"] == "Dream"]

ejercicio10 = ejercicio10.reset_index(drop=True)

ejercicio10
# Out:
#        species  bill_length_mm  bill_depth_mm
# 0       Adelie            39.5           16.7
# 1       Adelie            37.2           18.1
# 2       Adelie            39.5           17.8
# 3       Adelie            40.9           18.9
# 4       Adelie            36.4           17.0
# ..         ...             ...            ...
# 118  Chinstrap            55.8           19.8
# 119  Chinstrap            43.5           18.1
# 120  Chinstrap            49.6           18.2
# 121  Chinstrap            50.8           19.0
# 122  Chinstrap            50.2           18.7
#
# [123 rows x 3 columns]

# %% [markdown]
# ### b

# %%
ejercicio10 = ejercicio10[[col for col in ejercicio10.columns if col == "species" or col.startswith("bill")]]

ejercicio10.reset_index(drop=True)
# Out:
#        species  bill_length_mm  bill_depth_mm
# 0       Adelie            39.5           16.7
# 1       Adelie            37.2           18.1
# 2       Adelie            39.5           17.8
# 3       Adelie            40.9           18.9
# 4       Adelie            36.4           17.0
# ..         ...             ...            ...
# 118  Chinstrap            55.8           19.8
# 119  Chinstrap            43.5           18.1
# 120  Chinstrap            49.6           18.2
# 121  Chinstrap            50.8           19.0
# 122  Chinstrap            50.2           18.7
#
# [123 rows x 3 columns]

# %% [markdown]
# ## Ejercicio 11

# %% [markdown]
# ### a

# %%
ejercicio11 = sns.load_dataset("penguins").dropna().reset_index(drop=True)

ejercicio11['body_mass_g'] = ejercicio11['body_mass_g']/1000

ejercicio11 = ejercicio11.rename(columns={'body_mass_g':'body_mass_kg'})

ejercicio11.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen            36.7           19.3              193.0
# 4  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_kg     sex
# 0          3.75    Male
# 1          3.80  Female
# 2          3.25  Female
# 3          3.45  Female
# 4          3.65    Male

# %% [markdown]
# ### b

# %%
ejercicio11['island'] = ejercicio11['island'].apply(lambda x : x.lower())

ejercicio11.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  torgersen            39.1           18.7              181.0
# 1  Adelie  torgersen            39.5           17.4              186.0
# 2  Adelie  torgersen            40.3           18.0              195.0
# 3  Adelie  torgersen            36.7           19.3              193.0
# 4  Adelie  torgersen            39.3           20.6              190.0
#
#    body_mass_kg     sex
# 0          3.75    Male
# 1          3.80  Female
# 2          3.25  Female
# 3          3.45  Female
# 4          3.65    Male

# %% [markdown]
# ## Ejercicio 12

# %%
ejercicio12 = sns.load_dataset("penguins").dropna().reset_index(drop=True)
